# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
ad_clicks_csv = pd.read_csv('Social_Network_Ads.csv')
ad_clicks = ad_clicks_csv.drop('User ID',1)
ad_clicks
# Out:
#      Gender  Age  EstimatedSalary  Purchased
# 0      Male   19            19000          0
# 1      Male   35            20000          0
# 2    Female   26            43000          0
# 3    Female   27            57000          0
# 4      Male   19            76000          0
# ..      ...  ...              ...        ...
# 395  Female   46            41000          1
# 396    Male   51            23000          1
# 397  Female   50            20000          1
# 398    Male   36            33000          0
# 399  Female   49            36000          1
#
# [400 rows x 4 columns]

# %%
ad_clicks.describe().T
# Out:
#                  count        mean           std      min       25%      50%  \
# Age              400.0     37.6550     10.482877     18.0     29.75     37.0
# EstimatedSalary  400.0  69742.5000  34096.960282  15000.0  43000.00  70000.0
# Purchased        400.0      0.3575      0.479864      0.0      0.00      0.0
#
#                      75%       max
# Age                 46.0      60.0
# EstimatedSalary  88000.0  150000.0
# Purchased            1.0       1.0

# %% [markdown]
# Categorical Variables

# %%
categorical = [var for var in ad_clicks.columns if ad_clicks[var].dtype=='O']

print('There are {} categorical variables\n'.format(len(categorical)))

print('The categorical variables are :\n\n', categorical)
# Out:
# There are 1 categorical variables
#
# The categorical variables are :
#
#  ['Gender']

# %%
for var in categorical: 
    
    print(ad_clicks[var].value_counts())
# Out:
# Female    204
# Male      196
# Name: Gender, dtype: int64

# %%
for var in categorical:
    
     print(ad_clicks[var].value_counts()/np.float(len(ad_clicks)))
# Out:
# Female    0.51
# Male      0.49
# Name: Gender, dtype: float64

# %%
ad_clicks['Purchased'].nunique()
# Out:
# 2

# %%
ad_clicks['Purchased'].unique()
# Out:
# array([0, 1])

# %%
ad_clicks['Purchased'].value_counts()
# Out:
# 0    257
# 1    143
# Name: Purchased, dtype: int64

# %% [markdown]
# Frequency Distribution of Ad Clicks - Purchased/Unpurchased

# %%
# visualize frequency distribution of income variable

f,ax=plt.subplots(1,2,figsize=(18,8))

ax[0] = ad_clicks['Purchased'].value_counts().plot.pie(explode=[0,0],autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title('Ad Clicks')


#f, ax = plt.subplots(figsize=(6, 8))
ax[1] = sns.countplot(x="Purchased", data=ad_clicks, palette="Set1")
ax[1].set_title("Frequency distribution of Ad Clicks")

plt.show()
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/tools.py:331: MatplotlibDeprecationWarning:
# The is_first_col function was deprecated in Matplotlib 3.4 and will be removed two minor releases later. Use ax.get_subplotspec().is_first_col() instead.
#   if ax.is_first_col():

# %% [markdown]
# Distribution of Ad Clicks by Gender - Purchased/Unpurchased

# %%
f, ax = plt.subplots(figsize=(10, 8))
ax = sns.countplot(x="Purchased", hue="Gender", data=ad_clicks, palette="Set1")
ax.set_title("Frequency distribution of Purchased/Unpurchased variable wrt gender")
plt.show()

# %% [markdown]
# Numerical Variables

# %%
numerical = [var for var in ad_clicks.columns if ad_clicks[var].dtype!='O']

print('There are {} numerical variables\n'.format(len(numerical)))

print('The numerical variables are :\n\n', numerical)
# Out:
# There are 3 numerical variables
#
# The numerical variables are :
#
#  ['Age', 'EstimatedSalary', 'Purchased']

# %%
ad_clicks[numerical].head()
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0
# 3   27            57000          0
# 4   19            76000          0

# %%
ad_clicks['Age'].nunique()
# Out:
# 43

# %% [markdown]
# Age Distribution

# %%
f, ax = plt.subplots(figsize=(10,8))
x = ad_clicks['Age']
x = pd.Series(x, name="Age variable") #informative axis label 
ax = sns.distplot(x, bins=10, color='blue')
sns.set(style='whitegrid')
ax.set_title("Distribution of age variable")
plt.show()

# %%
f, ax = plt.subplots(figsize=(10,8))
x = ad_clicks['Age']
x = pd.Series(x, name="Age variable")
ax = sns.kdeplot(x, shade=True, color='red')
ax.set_title("Distribution of age variable")
plt.show()

# %%
#Detect outliers
f, ax = plt.subplots(figsize=(10,8))
x = ad_clicks['Age']
ax = sns.boxplot(x)
ax.set_title("Visualize outliers in age variable")
plt.show()

# %% [markdown]
# Age and Purchased/Unpurchased

# %%
f, ax = plt.subplots(figsize=(10, 8))
ax = sns.boxplot(x="Purchased", y="Age", data=ad_clicks)
ax.set_title("Visualize Purchased/Unpurchased wrt age variable")
plt.show()

# %% [markdown]
# Age and Gender, Purchased/Unpurchased

# %%
f, ax = plt.subplots(figsize=(10, 8))
ax = sns.boxplot(x="Purchased", y="Age", hue="Gender", data=ad_clicks)
ax.set_title("Visualize Purchased/Unpurchased wrt Age and Gender variable")
ax.legend(loc='upper right')
plt.show()

# %% [markdown]
# Gender-Age Distribution, Purchased/Unpurchased

# %%
plt.figure(figsize=(8,6))
ax = sns.catplot(x="Purchased", y="Age", col="Gender", data=ad_clicks, kind="box", height=8, aspect=1)
plt.show()

# %% [markdown]
# Salary Variable

# %%
f, ax = plt.subplots(figsize=(10,8))
x = ad_clicks['EstimatedSalary']
x = pd.Series(x, name="Salary variable") #informative axis label 
ax = sns.distplot(x, bins=10, color='blue')
ax.set_title("Distribution of Salary variable")
plt.show()

# %%
#Detect outliers
f, ax = plt.subplots(figsize=(10,8))
x = ad_clicks['EstimatedSalary']
ax = sns.boxplot(x)
ax.set_title("Visualize outliers in Salary variable")
plt.show()

# %% [markdown]
# Salary, Purchased/Unpurchased

# %%
f, ax = plt.subplots(figsize=(10, 8))
ax = sns.boxplot(x="Purchased", y="EstimatedSalary", data=ad_clicks)
ax.set_title("Visualize Purchased/Unpurchased wrt Salary variable")
plt.show()

# %% [markdown]
# Salary and Gender, Purchased/Unpurchased

# %%
f, ax = plt.subplots(figsize=(10, 8))
ax = sns.boxplot(x="Purchased", y="EstimatedSalary", hue="Gender", data=ad_clicks)
ax.set_title("Visualize Purchased/Unpurchased wrt Salary and Gender variable")
ax.legend(loc='upper right')
plt.show()

# %% [markdown]
# Salary-Gender Distribution, Purchased/Unpurchased

# %%
plt.figure(figsize=(8,6))
ax = sns.catplot(x="Purchased", y="EstimatedSalary", col="Gender", data=ad_clicks, kind="box", height=8, aspect=1)
plt.show()

# %%
ad_clicks.corr().style.format("{:.4}").background_gradient(cmap=plt.get_cmap('coolwarm'), axis=1)
# Out:
# <style  type="text/css" >
#     #T_099230b4_3d0e_11ec_bb55_8c859077f027row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_099230b4_3d0e_11ec_bb55_8c859077f027row0_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_099230b4_3d0e_11ec_bb55_8c859077f027row0_col2 {
#             background-color:  #ead5c9;
#             color:  #000000;
#         }    #T_099230b4_3d0e_11ec_bb55_8c859077f027row1_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_099230b4_3d0e_11ec_bb55_8c859077f027row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_099230b4_3d0e_11ec_bb55_8c859077f027row1_col2 {
#             background-color:  #8badfd;
#             color:  #000000;
#         }    #T_099230b4_3d0e_11ec_bb55_8c859077f027row2_col0 {
#             background-color:  #c3d5f4;
#             color:  #000000;
#         }    #T_099230b4_3d0e_11ec_bb55_8c859077f027row2_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_099230b4_3d0e_11ec_bb55_8c859077f027row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }</style><table id="T_099230b4_3d0e_11ec_bb55_8c859077f027" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Age</th>        <th class="col_heading level0 col1" >EstimatedSalary</th>        <th class="col_heading level0 col2" >Purchased</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_099230b4_3d0e_11ec_bb55_8c859077f027level0_row0" class="row_heading level0 row0" >Age</th>
#                         <td id="T_099230b4_3d0e_11ec_bb55_8c859077f027row0_col0" class="data row0 col0" >1.0</td>
#                         <td id="T_099230b4_3d0e_11ec_bb55_8c859077f027row0_col1" class="data row0 col1" >0.1552</td>
#                         <td id="T_099230b4_3d0e_11ec_bb55_8c859077f027row0_col2" class="data row0 col2" >0.6225</td>
#             </tr>
#             <tr>
#                         <th id="T_099230b4_3d0e_11ec_bb55_8c859077f027level0_row1" class="row_heading level0 row1" >EstimatedSalary</th>
#                         <td id="T_099230b4_3d0e_11ec_bb55_8c859077f027row1_col0" class="data row1 col0" >0.1552</td>
#                         <td id="T_099230b4_3d0e_11ec_bb55_8c859077f027row1_col1" class="data row1 col1" >1.0</td>
#                         <td id="T_099230b4_3d0e_11ec_bb55_8c859077f027row1_col2" class="data row1 col2" >0.3621</td>
#             </tr>
#             <tr>
#                         <th id="T_099230b4_3d0e_11ec_bb55_8c859077f027level0_row2" class="row_heading level0 row2" >Purchased</th>
#                         <td id="T_099230b4_3d0e_11ec_bb55_8c859077f027row2_col0" class="data row2 col0" >0.6225</td>
#                         <td id="T_099230b4_3d0e_11ec_bb55_8c859077f027row2_col1" class="data row2 col1" >0.3621</td>
#                         <td id="T_099230b4_3d0e_11ec_bb55_8c859077f027row2_col2" class="data row2 col2" >1.0</td>
#             </tr>
#     </tbody></table>

# %%
ad_clicks
# Out:
#      Gender  Age  EstimatedSalary  Purchased
# 0      Male   19            19000          0
# 1      Male   35            20000          0
# 2    Female   26            43000          0
# 3    Female   27            57000          0
# 4      Male   19            76000          0
# ..      ...  ...              ...        ...
# 395  Female   46            41000          1
# 396    Male   51            23000          1
# 397  Female   50            20000          1
# 398    Male   36            33000          0
# 399  Female   49            36000          1
#
# [400 rows x 4 columns]

# %% [markdown]
# Target Age Distributions

# %%
min_value = ad_clicks['Age'].min()
max_value = ad_clicks['Age'].max()
print(min_value, max_value)
age_bins_ar2 = np.linspace(min_value,max_value,5)
print(age_bins_ar2)
# Out:
# 18 60
# [18.  28.5 39.  49.5 60. ]

# %%
age18_25 = ad_clicks.loc[(ad_clicks.Age <= 25) & (ad_clicks.Age >= 18)]
age26_35 = ad_clicks.loc[(ad_clicks.Age <= 35) & (ad_clicks.Age >= 26)]
age36_45 = ad_clicks.loc[(ad_clicks.Age <= 45) & (ad_clicks.Age >= 36)]
age46_55 = ad_clicks.loc[(ad_clicks.Age <= 55) & (ad_clicks.Age >= 46)]
age55above = ad_clicks.loc[ad_clicks.Age >= 56]

x = ["18-25","26-35","36-45","46-55","55+"]
y = [len(age18_25.values),len(age26_35.values),len(age36_45.values),len(age46_55.values),len(age55above.values)]
y2= [(age18_25.values),(age26_35.values),(age36_45.values),(age46_55.values),(age55above.values)]
plt.figure(figsize=(15,6))
sns.barplot(x=x, y=y, palette="rocket")
plt.title("Number of Customer and Ages")
plt.xlabel("Age")
plt.ylabel("Number of Customer")
plt.show()

# %%
y_sum = sum(y)
y_array = np.asarray(y)
print(y_array)
perc_list = y_array/y_sum
print(perc_list)
perc_val = perc_list*100
print(perc_val)
# Out:
# [ 49 129 119  75  28]
# [0.1225 0.3225 0.2975 0.1875 0.07  ]
# [12.25 32.25 29.75 18.75  7.  ]

# %%
dict = {'Age Group': x, 'Total Count': y_array, 'Percentage of Users': perc_val}
age_df = pd.DataFrame(dict)
age_df.style.format({'Percentage of Users': '{0:.2f}%'.format,})
# Out:
# <style  type="text/css" >
# </style><table id="T_09b00256_3d0e_11ec_bb55_8c859077f027" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Age Group</th>        <th class="col_heading level0 col1" >Total Count</th>        <th class="col_heading level0 col2" >Percentage of Users</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_09b00256_3d0e_11ec_bb55_8c859077f027level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_09b00256_3d0e_11ec_bb55_8c859077f027row0_col0" class="data row0 col0" >18-25</td>
#                         <td id="T_09b00256_3d0e_11ec_bb55_8c859077f027row0_col1" class="data row0 col1" >49</td>
#                         <td id="T_09b00256_3d0e_11ec_bb55_8c859077f027row0_col2" class="data row0 col2" >12.25%</td>
#             </tr>
#             <tr>
#                         <th id="T_09b00256_3d0e_11ec_bb55_8c859077f027level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_09b00256_3d0e_11ec_bb55_8c859077f027row1_col0" class="data row1 col0" >26-35</td>
#                         <td id="T_09b00256_3d0e_11ec_bb55_8c859077f027row1_col1" class="data row1 col1" >129</td>
#                         <td id="T_09b00256_3d0e_11ec_bb55_8c859077f027row1_col2" class="data row1 col2" >32.25%</td>
#             </tr>
#             <tr>
#                         <th id="T_09b00256_3d0e_11ec_bb55_8c859077f027level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_09b00256_3d0e_11ec_bb55_8c859077f027row2_col0" class="data row2 col0" >36-45</td>
#                         <td id="T_09b00256_3d0e_11ec_bb55_8c859077f027row2_col1" class="data row2 col1" >119</td>
#                         <td id="T_09b00256_3d0e_11ec_bb55_8c859077f027row2_col2" class="data row2 col2" >29.75%</td>
#             </tr>
#             <tr>
#                         <th id="T_09b00256_3d0e_11ec_bb55_8c859077f027level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_09b00256_3d0e_11ec_bb55_8c859077f027row3_col0" class="data row3 col0" >46-55</td>
#                         <td id="T_09b00256_3d0e_11ec_bb55_8c859077f027row3_col1" class="data row3 col1" >75</td>
#                         <td id="T_09b00256_3d0e_11ec_bb55_8c859077f027row3_col2" class="data row3 col2" >18.75%</td>
#             </tr>
#             <tr>
#                         <th id="T_09b00256_3d0e_11ec_bb55_8c859077f027level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_09b00256_3d0e_11ec_bb55_8c859077f027row4_col0" class="data row4 col0" >55+</td>
#                         <td id="T_09b00256_3d0e_11ec_bb55_8c859077f027row4_col1" class="data row4 col1" >28</td>
#                         <td id="T_09b00256_3d0e_11ec_bb55_8c859077f027row4_col2" class="data row4 col2" >7.00%</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# Target Age Group, Gender Distribution

# %%
#(Gender values converted to numerical binary) 0 = M
age18_25f = ad_clicks.loc[(ad_clicks.Age <= 25) & (ad_clicks.Age >= 18) & (ad_clicks.Gender == 1)]
age18_25m = ad_clicks.loc[(ad_clicks.Age <= 25) & (ad_clicks.Age >= 18) & (ad_clicks.Gender == 0)]

age26_35f = ad_clicks.loc[(ad_clicks.Age <= 35) & (ad_clicks.Age >= 26) & (ad_clicks.Gender == 1)]
age26_35m = ad_clicks.loc[(ad_clicks.Age <= 35) & (ad_clicks.Age >= 26) & (ad_clicks.Gender == 0)]

age36_45f = ad_clicks.loc[(ad_clicks.Age <= 45) & (ad_clicks.Age >= 36) & (ad_clicks.Gender == 1)]
age36_45m = ad_clicks.loc[(ad_clicks.Age <= 45) & (ad_clicks.Age >= 36) & (ad_clicks.Gender == 0)]

age46_55f = ad_clicks.loc[(ad_clicks.Age <= 55) & (ad_clicks.Age >= 46) & (ad_clicks.Gender == 1)]
age46_55m = ad_clicks.loc[(ad_clicks.Age <= 55) & (ad_clicks.Age >= 46) & (ad_clicks.Gender == 0)]

age55abovef = ad_clicks.loc[(ad_clicks.Age >= 56) & (ad_clicks.Gender == 1)]
age55abovem = ad_clicks.loc[(ad_clicks.Age >= 56) & (ad_clicks.Gender == 0)]

x =  ["18-25","26-35","36-45","46-55","55+"]
yf = [len(age18_25f.values),len(age26_35f.values),len(age36_45f.values),len(age46_55f.values),len(age55abovef.values)]
ym = [len(age18_25m.values),len(age26_35m.values),len(age36_45m.values),len(age46_55m.values),len(age55abovem.values)]

dict2 = {'Age Group': x, 'Female Count': yf, 'Male Count':ym}
age_gender_df = pd.DataFrame(dict2)
age_gender_df
# Out:
#   Age Group  Female Count  Male Count
# 0     18-25             0           0
# 1     26-35             0           0
# 2     36-45             0           0
# 3     46-55             0           0
# 4       55+             0           0

# %% [markdown]
# #Calculate Age Group - Gender Subarray ; Purchased/Unpurchased (repeat charts)

# %% [markdown]
# Target Estimated Salary Distribution

# %%
es0_30 = ad_clicks['EstimatedSalary'][(ad_clicks['EstimatedSalary'] >= 0) & (ad_clicks['EstimatedSalary'] <= 30000)]
es31_60 = ad_clicks['EstimatedSalary'][(ad_clicks['EstimatedSalary'] >= 31000) & (ad_clicks['EstimatedSalary'] <= 60000)]
es61_90 = ad_clicks['EstimatedSalary'][(ad_clicks['EstimatedSalary'] >= 61000) & (ad_clicks['EstimatedSalary'] <= 90000)]
es91_120 = ad_clicks['EstimatedSalary'][(ad_clicks['EstimatedSalary'] >= 91000) & (ad_clicks['EstimatedSalary'] <= 120000)]
es121_150 = ad_clicks['EstimatedSalary'][(ad_clicks['EstimatedSalary'] >= 121000) & (ad_clicks['EstimatedSalary'] <= 150000)]

esx = ["$ 0 - 30,000", "$ 30,001 - 60,000", "$ 60,001 - 90,000", "$ 90,001 - 120,000", "$ 120,001 - 150,000"]
esy = [len(es0_30.values), len(es31_60.values), len(es61_90.values), len(es91_120.values), len(es121_150.values)]

plt.figure(figsize=(15,6))
sns.barplot(x=esx, y=esy, palette="Set2")
plt.title("Annual Incomes")
plt.xlabel("Income")
plt.ylabel("Number of Customer")
plt.show()

# %%
esy_sum = sum(esy)
esy_array = np.asarray(esy)
print(esy_array)
esperc_list = esy_array/esy_sum
print(esperc_list)
esperc_val = esperc_list*100
print(esperc_val)
# Out:
# [ 57 117 143  42  41]
# [0.1425 0.2925 0.3575 0.105  0.1025]
# [14.25 29.25 35.75 10.5  10.25]

# %%
dict = {'Salary Group': esx, 'Total Count': esy_array, 'Percentage of Users': esperc_val}
salary_df = pd.DataFrame(dict)
salary_df.style.format({'Percentage of Users': '{0:.2f}%'.format,})
# Out:
# <style  type="text/css" >
# </style><table id="T_09d209e6_3d0e_11ec_bb55_8c859077f027" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Salary Group</th>        <th class="col_heading level0 col1" >Total Count</th>        <th class="col_heading level0 col2" >Percentage of Users</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_09d209e6_3d0e_11ec_bb55_8c859077f027level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_09d209e6_3d0e_11ec_bb55_8c859077f027row0_col0" class="data row0 col0" >$ 0 - 30,000</td>
#                         <td id="T_09d209e6_3d0e_11ec_bb55_8c859077f027row0_col1" class="data row0 col1" >57</td>
#                         <td id="T_09d209e6_3d0e_11ec_bb55_8c859077f027row0_col2" class="data row0 col2" >14.25%</td>
#             </tr>
#             <tr>
#                         <th id="T_09d209e6_3d0e_11ec_bb55_8c859077f027level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_09d209e6_3d0e_11ec_bb55_8c859077f027row1_col0" class="data row1 col0" >$ 30,001 - 60,000</td>
#                         <td id="T_09d209e6_3d0e_11ec_bb55_8c859077f027row1_col1" class="data row1 col1" >117</td>
#                         <td id="T_09d209e6_3d0e_11ec_bb55_8c859077f027row1_col2" class="data row1 col2" >29.25%</td>
#             </tr>
#             <tr>
#                         <th id="T_09d209e6_3d0e_11ec_bb55_8c859077f027level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_09d209e6_3d0e_11ec_bb55_8c859077f027row2_col0" class="data row2 col0" >$ 60,001 - 90,000</td>
#                         <td id="T_09d209e6_3d0e_11ec_bb55_8c859077f027row2_col1" class="data row2 col1" >143</td>
#                         <td id="T_09d209e6_3d0e_11ec_bb55_8c859077f027row2_col2" class="data row2 col2" >35.75%</td>
#             </tr>
#             <tr>
#                         <th id="T_09d209e6_3d0e_11ec_bb55_8c859077f027level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_09d209e6_3d0e_11ec_bb55_8c859077f027row3_col0" class="data row3 col0" >$ 90,001 - 120,000</td>
#                         <td id="T_09d209e6_3d0e_11ec_bb55_8c859077f027row3_col1" class="data row3 col1" >42</td>
#                         <td id="T_09d209e6_3d0e_11ec_bb55_8c859077f027row3_col2" class="data row3 col2" >10.50%</td>
#             </tr>
#             <tr>
#                         <th id="T_09d209e6_3d0e_11ec_bb55_8c859077f027level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_09d209e6_3d0e_11ec_bb55_8c859077f027row4_col0" class="data row4 col0" >$ 120,001 - 150,000</td>
#                         <td id="T_09d209e6_3d0e_11ec_bb55_8c859077f027row4_col1" class="data row4 col1" >41</td>
#                         <td id="T_09d209e6_3d0e_11ec_bb55_8c859077f027row4_col2" class="data row4 col2" >10.25%</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# #Calculate Salary Group - Gender Subarray ; Purchased/Unpurchased

# %% [markdown]
# Ex: representative percentage of purchased if white woman aged 31 with salary of 37k

# %%
#predictive percentage of purchased if white woman aged 31 with salary of 37k
gender_selection = ad_clicks.loc[ad_clicks['Gender'] == 'Female']
age_selection = gender_selection.loc[gender_selection['Age'] == 31]
count_selection = age_selection.loc[age_selection['Purchased'] == 0]
sel_count = count_selection['Purchased'].count()
total = ad_clicks['Purchased'].count()
perc = sel_count/total*100
print(f"Predictive purchase percentage of F/31/37K is {perc}%")
#not correct as this only accounts for sample
# Out:
# Predictive purchase percentage of F/31/37K is 1.25%

# %% [markdown]
# Groupby Gender, Purchased

# %%
multi = ad_clicks.groupby(['Purchased', 'Gender']).agg({'Age': ['count'], 'EstimatedSalary':['mean'] })
multi_fill = multi.fillna(0)
multi_fill
# Out:
#                    Age EstimatedSalary
#                  count            mean
# Purchased Gender
# 0         Female   127    61480.314961
#           Male     130    59630.769231
# 1         Female    77    88714.285714
#           Male      66    83424.242424

# %%
multi = ad_clicks.groupby(['Gender', 'Purchased']).agg({'Age': ['count'], 'EstimatedSalary':['mean'] })
multi
# Out:
#                    Age EstimatedSalary
#                  count            mean
# Gender Purchased
# Female 0           127    61480.314961
#        1            77    88714.285714
# Male   0           130    59630.769231
#        1            66    83424.242424

# %%
plt.figure(figsize=(15,7))
sns.scatterplot(data=ad_clicks,x='Age',y='EstimatedSalary',hue='Purchased',style='Gender')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='EstimatedSalary'>

# %% [markdown]
# Descriptive Analysis

# %%
ad_clicks.describe().T
# Out:
#                  count        mean           std      min       25%      50%  \
# Age              400.0     37.6550     10.482877     18.0     29.75     37.0
# EstimatedSalary  400.0  69742.5000  34096.960282  15000.0  43000.00  70000.0
# Purchased        400.0      0.3575      0.479864      0.0      0.00      0.0
#
#                      75%       max
# Age                 46.0      60.0
# EstimatedSalary  88000.0  150000.0
# Purchased            1.0       1.0

# %%
ad_clicks2 = ad_clicks
ad_clicks2['Gender'] = ad_clicks2['Gender'].map({"Male":0, "Female":1})
ad_clicks2
# Out:
#      Gender  Age  EstimatedSalary  Purchased
# 0         0   19            19000          0
# 1         0   35            20000          0
# 2         1   26            43000          0
# 3         1   27            57000          0
# 4         0   19            76000          0
# ..      ...  ...              ...        ...
# 395       1   46            41000          1
# 396       0   51            23000          1
# 397       1   50            20000          1
# 398       0   36            33000          0
# 399       1   49            36000          1
#
# [400 rows x 4 columns]

# %%
ad_clicks2.describe().T
# Out:
#                  count        mean           std      min       25%      50%  \
# Gender           400.0      0.5100      0.500526      0.0      0.00      1.0
# Age              400.0     37.6550     10.482877     18.0     29.75     37.0
# EstimatedSalary  400.0  69742.5000  34096.960282  15000.0  43000.00  70000.0
# Purchased        400.0      0.3575      0.479864      0.0      0.00      0.0
#
#                      75%       max
# Gender               1.0       1.0
# Age                 46.0      60.0
# EstimatedSalary  88000.0  150000.0
# Purchased            1.0       1.0

# %% [markdown]
# Binary Logistic Regression

# %%
from sklearn.model_selection import train_test_split

train_data, test_data = train_test_split(ad_clicks2, test_size=.2, random_state=42)

# %%
import statsmodels.api as sm
from statsmodels.formula.api import logit

formula = ('Purchased ~ Age + EstimatedSalary + Gender')
model = logit(formula=formula, data=train_data).fit()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.371365
#          Iterations 7

# %% [markdown]
# Model Summary

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:              Purchased   No. Observations:                  320
# Model:                          Logit   Df Residuals:                      316
# Method:                           MLE   Df Model:                            3
# Date:                Wed, 03 Nov 2021   Pseudo R-squ.:                  0.4313
# Time:                        21:25:05   Log-Likelihood:                -118.84
# converged:                       True   LL-Null:                       -208.98
# Covariance Type:            nonrobust   LLR p-value:                 7.661e-39
# ===================================================================================
#                       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept         -11.4195      1.324     -8.624      0.000     -14.015      -8.824
# Age                 0.2113      0.027      7.923      0.000       0.159       0.264
# EstimatedSalary  3.591e-05   5.76e-06      6.233      0.000    2.46e-05    4.72e-05
# Gender             -0.3156      0.328     -0.961      0.337      -0.959       0.328
# ===================================================================================
# """

# %% [markdown]
# The coefficient scores show that Age and Estimated Salary have a significant influence on Purchased/UnPurchased (p-values <0.05).

# %% [markdown]
# Marginal Effects Computation

# %%
AME = model.get_margeff(at='overall', method='dydx')
print(AME.summary())
# Out:
#         Logit Marginal Effects
# =====================================
# Dep. Variable:              Purchased
# Method:                          dydx
# At:                           overall
# ===================================================================================
#                      dy/dx    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Age                 0.0252      0.002     14.625      0.000       0.022       0.029
# EstimatedSalary  4.285e-06   5.05e-07      8.485      0.000     3.3e-06    5.27e-06
# Gender             -0.0377      0.039     -0.965      0.334      -0.114       0.039
# ===================================================================================

# %% [markdown]
# Confusion Matrix

# %%
import numpy as np 
from sklearn.metrics import classification_report, accuracy_score

prediction = model.predict(exog= test_data)
cutoff =.5
y_prediction = np.where(prediction> cutoff,1,0)
y_actual = test_data['Purchased']

conf_matrix = pd.crosstab(y_actual, y_prediction, rownames= ["Actual"], colnames=['Predicted'], margins=True)

print(conf_matrix)
# Out:
# Predicted   0   1  All
# Actual
# 0          50   2   52
# 1           7  21   28
# All        57  23   80

# %% [markdown]
# Test dataset has 52 Purchased, and 28 Not Purchased, the trained model
# classified 50 Purchased, and 21 Not Purchased accurately.

# %% [markdown]
# Classification Accuracy

# %%
accuracy = accuracy_score(y_actual, y_prediction)
print('Prediction Accuracy: %.2f' % accuracy + "%")
# Out:
# Prediction Accuracy: 0.89%

# %% [markdown]
# Classification Report

# %%
print(classification_report(y_actual, y_prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.96      0.92        52
#            1       0.91      0.75      0.82        28
#
#     accuracy                           0.89        80
#    macro avg       0.90      0.86      0.87        80
# weighted avg       0.89      0.89      0.88        80

# %% [markdown]
# K-Means Optimal Clusters - WCSS

# %%
test = ad_clicks.iloc[:,1:]
test.head()
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0
# 3   27            57000          0
# 4   19            76000          0

# %%
from sklearn.cluster import KMeans
X2=ad_clicks[["Age","EstimatedSalary","Purchased"]]
wcss = []
for k in range(1,11):
    kmeans = KMeans(n_clusters=k, init="k-means++")
    kmeans.fit(ad_clicks.iloc[:,1:])
    wcss.append(kmeans.inertia_)
plt.figure(figsize=(12,6))    
plt.grid()
plt.plot(range(1,11),wcss, linewidth=2, color="red", marker ="8")
plt.xlabel("K Value")
plt.xticks(np.arange(1,11,1))
plt.ylabel("WCSS")
plt.show()

# %% [markdown]
# K-Means Clustering POC

# %%
km = KMeans(n_clusters=3)
clusters = km.fit_predict(ad_clicks.iloc[:,1:])
ad_clicks["label"] = clusters
ad_clicks.head()
# Out:
#    Gender  Age  EstimatedSalary  Purchased  label
# 0       0   19            19000          0      2
# 1       0   35            20000          0      2
# 2       1   26            43000          0      2
# 3       1   27            57000          0      1
# 4       0   19            76000          0      1

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
 
fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(ad_clicks.Age[ad_clicks.label == 0], ad_clicks["EstimatedSalary"][ad_clicks.label == 0], ad_clicks["Purchased"][ad_clicks.label == 0], c='blue', s=60)
ax.scatter(ad_clicks.Age[ad_clicks.label == 1], ad_clicks["EstimatedSalary"][ad_clicks.label == 1], ad_clicks["Purchased"][ad_clicks.label == 1], c='red', s=60)
ax.scatter(ad_clicks.Age[ad_clicks.label == 2], ad_clicks["EstimatedSalary"][ad_clicks.label == 2], ad_clicks["Purchased"][ad_clicks.label == 2], c='green', s=60)
ax.view_init(30, 185)
plt.xlabel("Age")
plt.ylabel("EstimatedSalary")
ax.set_zlabel('Purchased')
plt.show()

# %% [markdown]
# Determining Clusters & Sub-Clusters from Model<br>
# <p>Determined 3 optimal clusters to be of Salary Range each with 2 subclusters of Purchased/Unpurchased.
